# %%
import os

import pandas as pd

# %%
articlePath = (os.getcwd() + '/Articles/Article_Info.csv')
articles = pd.read_csv(articlePath)
articles.head()
# Out:
#                                                  URL  \
# 0  https://www.ibtimes.com/tesla-news-can-model-3...
# 1  https://www.ibtimes.com/how-elon-musk-will-cel...
# 2  https://www.ibtimes.com/spacex-ceo-elon-musk-m...
# 3  https://www.ibtimes.com/tesla-news-ceo-elon-mu...
# 4  https://www.ibtimes.com/where-will-tesla-be-1-...
#
#                                                Title          Author  \
# 0    Tesla News: Can Model 3 Deliveries Keep Rising?   Daniel Sparks
# 1  This Is How Elon Musk Will Celebrate His 48th ...      Dawn Geske
# 2  SpaceX CEO Elon Musk Mocked For Tweet Mixing U...  Wesley Dockery
# 3  Tesla News: CEO Elon Musk Said He Deleted His ...  Wesley Dockery
# 4                     Where Will Tesla Be In 1 Year?    John Bromels
#
#   Date_Published Time_Published  \
# 0       06/29/19        1:11 AM
# 1       06/28/19       12:09 PM
# 2       06/24/19        1:36 PM
# 3       06/17/19       12:19 PM
# 4       06/16/19       10:14 PM
#
#                                              Article
# 0  ["Next week,\xa0Tesla\xa0(NASDAQ:TSLA) investo...
# 1  ['As Elon Musk celebrates his 48th birthday on...
# 2  ['Tesla (TSLA) and SpaceX CEO Elon Musk was sl...
# 3  ['Tesla (TSLA) CEO Elon Musk on Monday morning...
# 4  ['To hear\xa0Tesla\xa0(NASDAQ:TSLA)\xa0CEO Elo...

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 6 columns):
# URL               567 non-null object
# Title             567 non-null object
# Author            567 non-null object
# Date_Published    567 non-null object
# Time_Published    567 non-null object
# Article           567 non-null object
# dtypes: object(6)
# memory usage: 26.7+ KB

# %%
# articles.Date_Published = pd.to_datetime(articles.Date_Published)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0b9028c346f5> in <module>
# ----> 1 articles.Date_Published = pd.to_datetime(articles.Date_Published)
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     461             errors=errors,
#     462             require_iso8601=require_iso8601,
# --> 463             allow_object=True,
#     464         )
#     465
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1982             return values.view("i8"), tz_parsed
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#    1986     if tz_parsed is not None:
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1973             dayfirst=dayfirst,
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#    1977     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# ~/Desktop/Hack_Rice_Stock_Prediction/venv/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', 'https://www.ibtimes.com/tesla-news-can-model-3-deliveries-keep-rising-2803693')

# %%
articles.head()
# Out:
#                                                  URL  \
# 0  https://www.ibtimes.com/tesla-news-can-model-3...
# 1  https://www.ibtimes.com/how-elon-musk-will-cel...
# 2  https://www.ibtimes.com/spacex-ceo-elon-musk-m...
# 3  https://www.ibtimes.com/tesla-news-ceo-elon-mu...
# 4  https://www.ibtimes.com/where-will-tesla-be-1-...
#
#                                                Title          Author  \
# 0    Tesla News: Can Model 3 Deliveries Keep Rising?   Daniel Sparks
# 1  This Is How Elon Musk Will Celebrate His 48th ...      Dawn Geske
# 2  SpaceX CEO Elon Musk Mocked For Tweet Mixing U...  Wesley Dockery
# 3  Tesla News: CEO Elon Musk Said He Deleted His ...  Wesley Dockery
# 4                     Where Will Tesla Be In 1 Year?    John Bromels
#
#                                       Date_Published Time_Published  \
# 0  https://www.ibtimes.com/tesla-news-can-model-3...        1:11 AM
# 1  https://www.ibtimes.com/how-elon-musk-will-cel...       12:09 PM
# 2  https://www.ibtimes.com/spacex-ceo-elon-musk-m...        1:36 PM
# 3  https://www.ibtimes.com/tesla-news-ceo-elon-mu...       12:19 PM
# 4  https://www.ibtimes.com/where-will-tesla-be-1-...       10:14 PM
#
#                                              Article
# 0  ["Next week,\xa0Tesla\xa0(NASDAQ:TSLA) investo...
# 1  ['As Elon Musk celebrates his 48th birthday on...
# 2  ['Tesla (TSLA) and SpaceX CEO Elon Musk was sl...
# 3  ['Tesla (TSLA) CEO Elon Musk on Monday morning...
# 4  ['To hear\xa0Tesla\xa0(NASDAQ:TSLA)\xa0CEO Elo...
