# %%
import pandas as pd
from pandas_datareader import data
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9bb07acf7eeb> in <module>
#       1 import pandas as pd
# ----> 2 from pandas_datareader import data
#       3 import os
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
def create_new_training_model(n):
    stock_data = pd.read_csv(os.getcwd() + "/Stock_Data/TSLA.csv")
    stock_data['Increase'] = 0
    new_stock_info = pd.DataFrame(columns = stock_data.columns)
    for i in range(0, len(stock_data)-n, n):
        start = stock_data.iloc[i].Close
        end = stock_data.iloc[i+n].Close
        
        if((end-start) > 0):
            for j in range(i,i+n):
                stock_data.set_value(j, 'Increase', 1)
        new_stock_info = new_stock_info.append(stock_data.iloc[i])
    new_stock_info.to_csv("TSLA_Training_Data.csv")            
    return new_stock_info
    

def get_interval_increase(day, n):
    for i in range(0, len(stock_data)-n, n):
        start_date = datetime.strptime(stock_data.iloc[i].Date, '%Y-%m-%d')
        end_date = datetime.strptime(stock_data.iloc[i+n].Date, '%Y-%m-%d')
        if start_date <= day <= end_date:
            return stock_data.iloc[i].Increase

stock_data = create_new_training_model(10)
print(get_interval_increase(datetime(2011, 3, 8), 10))
stock_data.head(22)
# Out:
# 1
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2010-06-29  19.000000  25.000000  17.540001  23.889999  23.889999
# 10   2010-07-14  17.940001  20.150000  17.760000  19.840000  19.840000
# 20   2010-07-28  20.549999  20.900000  20.510000  20.719999  20.719999
# 30   2010-08-11  18.690001  18.879999  17.850000  17.900000  17.900000
# 40   2010-08-25  19.160000  19.980000  18.559999  19.900000  19.900000
# 50   2010-09-09  21.000000  21.049999  20.690001  20.709999  20.709999
# 60   2010-09-23  19.889999  20.139999  19.500000  19.559999  19.559999
# 70   2010-10-07  20.570000  20.639999  20.340000  20.430000  20.430000
# 80   2010-10-21  20.610001  20.950001  20.450001  20.750000  20.750000
# 90   2010-11-04  22.600000  25.330000  22.150000  24.900000  24.900000
# 100  2010-11-18  30.670000  30.740000  28.920000  29.889999  29.889999
# 110  2010-12-03  32.009998  32.250000  30.870001  31.490000  31.490000
# 120  2010-12-17  31.340000  31.540001  30.709999  31.360001  31.360001
# 130  2011-01-03  26.840000  27.000000  25.900000  26.620001  26.620001
# 140  2011-01-18  25.480000  25.639999  24.750000  25.639999  25.639999
# 150  2011-02-01  24.309999  24.730000  23.540001  23.910000  23.910000
# 160  2011-02-15  23.010000  23.170000  22.559999  22.840000  22.840000
# 170  2011-03-02  23.820000  24.280001  23.730000  24.020000  24.020000
# 180  2011-03-16  22.860001  23.250000  22.690001  22.820000  22.820000
# 190  2011-03-30  24.110001  24.490000  23.010000  23.709999  23.709999
# 200  2011-04-13  25.129999  25.690001  24.809999  24.930000  24.930000
# 210  2011-04-28  27.070000  27.690001  26.719999  27.660000  27.660000
#
#        Volume Increase
# 0    18766300        0
# 10    4195200        1
# 20     467200        0
# 30     797600        1
# 40     503300        1
# 50     376200        0
# 60     668100        1
# 70     141000        1
# 80     417100        1
# 90    1874000        1
# 100    956100        1
# 110   1160100        0
# 120    813000        0
# 130   1283000        0
# 140   1621700        0
# 150    707800        0
# 160    953700        1
# 170    663300        0
# 180   1169700        1
# 190   1223300        1
# 200   1211500        1
# 210   1600000        1
